# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.shape
# Out:
# (150, 6)

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df1=pd.get_dummies(df,columns=['Species'])

# %%
df1
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#      Species_Iris-setosa  Species_Iris-versicolor  Species_Iris-virginica
# 0                   True                    False                   False
# ...

# %%
from sklearn import preprocessing
x=df[['SepalLengthCm']].values.astype(float)
min_max_scaler=preprocessing.MinMaxScaler()
x_scaled=min_max_scaler.fit_transform(x)
df_normalized=pd.DataFrame(x_scaled)
df_normalized
# Out:
#             0
# 0    0.222222
# 1    0.166667
# 2    0.111111
# 3    0.083333
# 4    0.194444
# ..        ...
# 145  0.666667
# 146  0.555556
# 147  0.611111
# 148  0.527778
# 149  0.444444
#
# [150 rows x 1 columns]

# %%
from sklearn import preprocessing
df['Species'].unique()
label_encoder=preprocessing.LabelEncoder()
df['Species']=label_encoder.fit_transform(df['Species'])
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        0
# 1      2            4.9           3.0            1.4           0.2        0
# 2      3            4.7           3.2            1.3           0.2        0
# 3      4            4.6           3.1            1.5           0.2        0
# 4      5            5.0           3.6            1.4           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]

# %%
from sklearn import preprocessing
df['Species'].unique()
# Out:
# array([0, 1, 2])

# %%
features_df=df.drop(columns=['Species'])

# %%
features_df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
# [150 rows x 5 columns]

# %%
enc=preprocessing.OneHotEncoder()
enc_df=pd.DataFrame(enc.fit_transform(df[['Species']])).to_numpy()

# %%
df_encode=features_df.join(enc_df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8936\133693443.py in ?()
# ----> 1 df_encode=features_df.join(enc_df)
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10781             # the LHS is an "Iterable[DataFrame]", but in reality both types are
#   10782             # "Iterable[Union[DataFrame, Series]]" due to the if statements
#   10783             frames = [cast("DataFrame | Series", self)] + list(other)
#   10784
# > 10785             can_concat = all(df.index.is_unique for df in frames)
#   10786
#   10787             # join indexes only using concat
#   10788             if can_concat:
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(.0)
# > 10785     def join(
#   10786         self,
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
df_pandas_encoded=pd.get_dummies(df,columns=['Species'])
print(f"One-Hot Encoded Data using Pandas:\n{df_pandas_encoded}\n")
encoder = OneHotEncoder(sparse_output=False)
# Out:
# One-Hot Encoded Data using Pandas:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species_0  \
# 0      1            5.1           3.5            1.4           0.2       True
# 1      2            4.9           3.0            1.4           0.2       True
# 2      3            4.7           3.2            1.3           0.2       True
# 3      4            4.6           3.1            1.5           0.2       True
# 4      5            5.0           3.6            1.4           0.2       True
# ..   ...            ...           ...            ...           ...        ...
# 145  146            6.7           3.0            5.2           2.3      False
# 146  147            6.3           2.5            5.0           1.9      False
# 147  148            6.5           3.0            5.2           2.0      False
# 148  149            6.2           3.4            5.4           2.3      False
# 149  150            5.9           3.0            5.1           1.8      False
# ...

# %%
enc=preprocessing.OneHotEncoder()
enc_df=pd.DataFrame(enc.fit_transform(df[['Species']]))
one_hot_df=pd.DataFrame(enc_df,columns=encoder.get_feature_names_out(df[['Species']]))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[77], line 3
#       1 enc=preprocessing.OneHotEncoder()
#       2 enc_df=pd.DataFrame(enc.fit_transform(df[['Species']]))
# ----> 3 one_hot_df=pd.DataFrame(enc_df,columns=encoder.get_feature_names_out(df[['Species']]))
#
# File ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_encoders.py:1226, in OneHotEncoder.get_feature_names_out(self, input_features)
#    1206 def get_feature_names_out(self, input_features=None):
#    1207     """Get output feature names for transformation.
#    1208
#    1209     Parameters
#    (...)
#    1224         Transformed feature names.
#    1225     """
# -> 1226     check_is_fitted(self)
#    1227     input_features = _check_feature_names_in(self, input_features)
#    1228     cats = [
#    1229         self._compute_transformed_categories(i)
# ...
