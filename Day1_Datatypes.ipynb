# %% [markdown]
# # List #Heterogeneous #Ordered=indexing is present #Mutable

# %%
l=[8,6,600,87,6,10,True,'ok']

# %%
type(l)
# Out:
# list

# %% [markdown]
# # Slicing

# %%
l[1:4]
# Out:
# [6, 7, True]

# %%
l[1::2]
# Out:
# [6, True]

# %%
l1=[2,5,8,44,23,2]

# %%
l1
# Out:
# [2, 5, 8, 44, 23, 2]

# %% [markdown]
# # Append

# %%
l1.append(700)

# %%
l1
# Out:
# [2, 5, 8, 44, 23, 2, 700]

# %% [markdown]
# # POP

# %%
l1.pop()
# Out:
# 700

# %%
l1
# Out:
# [2, 5, 8, 44, 23, 2]

# %% [markdown]
# # index

# %%
l1.index(8)
# Out:
# 2

# %% [markdown]
# # Remove

# %%
l1.remove(8)

# %%
l1
# Out:
# [2, 5, 44, 23, 2]

# %% [markdown]
# # insert

# %%
l1.insert(2,800)

# %%
l1
# Out:
# [2, 5, 800, 44, 23, 2]

# %% [markdown]
# # Empty list

# %%
e=[]

# %%
e[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 e[0]
#
# IndexError: list index out of range

# %%
l=[12,55,90,67,55,12,13]

# %% [markdown]
# # Iterate over the list and print their index and element

# %%
for i in l:
    print(f"{l.index(i)} -> {i}")
# Out:
# 0 -> 12
# 1 -> 55
# 2 -> 90
# 3 -> 67
# 1 -> 55
# 0 -> 12
# 6 -> 13

# %% [markdown]
# # enumerate

# %%
l=[(0,12),(1,55),(2,90),(3,67),(4,55),(5,12),(6,13)]

# %%
l
# Out:
# [(0, 12), (1, 55), (2, 90), (3, 67), (4, 55), (5, 12), (6, 13)]

# %%
for ind, val in enumerate(l):
    print(f"{ind} -> {val}")
# Out:
# 0 -> (0, 12)
# 1 -> (1, 55)
# 2 -> (2, 90)
# 3 -> (3, 67)
# 4 -> (4, 55)
# 5 -> (5, 12)
# 6 -> (6, 13)

# %% [markdown]
# # Tuple

# %% [markdown]
# T=(34,78,55,55,True)

# %%
help.enumerate()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 help.enumerate()
#
# AttributeError: '_Helper' object has no attribute 'enumerate'
