# %%
## take the user input and check if its positive or negative
n=int(input("Enter a number:"))
# Out:
# Enter a number: 5

# %%
if(n>0):
    print("Number is positive")
elif(n==0):
    print("It's 0")
else:
    print("Negative number")
# Out:
# Number is positive

# %%
## take the user input and check if its even or odd
n= int(input("Enter the number:"))
# Out:
# Enter the number: 4

# %%
if(n%2==0):
    print("Number is even")
else:
    print("Number is odd")
# Out:
# Number is even

# %%
## take the user input and check if the year is leap year or not
n= int(input("Enter a number:"))
# Out:
# Enter a number: 2000

# %%
if(n%4==0):
    if(n%100==0):
        if(n%400==0):
             print("Leap Century Year")
        else:
            print("century but not leap")
else:
    print ("not leap")
# Out:
# Leap Century Year

# %% [markdown]
# # Menu driven Program for Simple Calculator

# %%
print("Welcome to simple calculator")
num=float(input("Enter the number"))
print("MENU=> \n1. Square\n2. Cube\n3. Positive or Negative")
ch=int(input("Enter your choice"))
if ch==1:
    print(num*num)
elif ch==2:
    print(num*num*num)
else:
    print("please visit nearest eye clinic")
# Out:
# Welcome to simple calculator
# Enter the number 2
# MENU=>
# 1. Square
# 2. Cube
# 3. Positive or Negative
# Enter your choice 2
# 8.0

# %% [markdown]
# # Find the addition of Numbers from 1 to 10 using while loop using two variables

# %%
count=1
add=0
while count<=10:
    add=add+count
    count+=1
print("Addition is:",add)
# Out:
# Addition is: 55

# %% [markdown]
# # For Loop

# %%
for i in 78,98,56,True,"ok",3:
    print(i)
# Out:
# 78
# 98
# 56
# True
# ok
# 3

# %% [markdown]
# # Range Function
# # start=0,end=exclusive, step=1

# %%
list(range(5,11,2))
# Out:
# [5, 7, 9]

# %%
for i in range(1,11):
    print(i**2)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100

# %% [markdown]
# # Find the addition of Numbers from 1 to 10 using for loop using two variables

# %%
add=0
for i in range(1,11):
    add=add+i
print("Addition is:",add)
# Out:
# Addition is: 55

# %% [markdown]
# # Loop Control Statements # continue # break

# %%
for i in range(1,11):
    if i==6:
        break
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# # Find the addition of Numbers from 1 to 10 using while loop¶

# %%
i=1
add=0
while i<=10:
    add=add+i
    i+=1
print("Addition is:",add)
# Out:
# Addition is: 55
