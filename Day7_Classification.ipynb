# %%
# Decision Trees= Works on both regression & Classification problem
# Regression & Classification depends on nature of target variable
# For ordinal data one hot encoding is better
# When your dependent variable is binary then you can use logistic regression

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# arange function can take float values while range() function takes only int values

# %%
x=np.arange(-5,5,0.5)

# %%
x
# Out:
# array([-5. , -4.5, -4. , -3.5, -3. , -2.5, -2. , -1.5, -1. , -0.5,  0. ,
#         0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5,  4. ,  4.5])

# %%
y=6.7*x+53

# %%
y
# Out:
# array([19.5 , 22.85, 26.2 , 29.55, 32.9 , 36.25, 39.6 , 42.95, 46.3 ,
#        49.65, 53.  , 56.35, 59.7 , 63.05, 66.4 , 69.75, 73.1 , 76.45,
#        79.8 , 83.15])

# %%
plt.plot(x,y)

# %%
# Sigmoid Function
def sigmoid(x):
    return 1/(1+np.exp(-x))

# %%
y=sigmoid(x)

# %%
y
# Out:
# array([0.00669285, 0.01098694, 0.01798621, 0.02931223, 0.04742587,
#        0.07585818, 0.11920292, 0.18242552, 0.26894142, 0.37754067,
#        0.5       , 0.62245933, 0.73105858, 0.81757448, 0.88079708,
#        0.92414182, 0.95257413, 0.97068777, 0.98201379, 0.98901306])

# %%
plt.plot(x,y);
